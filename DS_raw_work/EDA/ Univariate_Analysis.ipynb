# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\titanic.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 756          757         0       3   Carlsson, Mr. August Sigfrid    male
# 159          160         0       3     Sage, Master. Thomas Henry    male
# 469          470         1       3  Baclini, Miss. Helene Barbara  female
# 414          415         1       3      Sundman, Mr. Johan Julian    male
# 392          393         0       3   Gustafsson, Mr. Johan Birger    male
#
#        Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 756  28.00      0      0             350042   7.7958   NaN        S
# 159    NaN      8      2           CA. 2343  69.5500   NaN        S
# 469   0.75      2      1               2666  19.2583   NaN        C
# 414  44.00      0      0  STON/O 2. 3101269   7.9250   NaN        S
# 392  28.00      2      0            3101277   7.9250   NaN        S

# %% [markdown]
# Univariate_analysis on categorical Data(single_column)

# %%
#Categorical columns

#survived , pclass , sex , sibsp , cabin ,embarked

# %%
#sns.countplot(df['Pclass'])
df['Embarked'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17344\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\placement.csv")
print(df)
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['placed'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='placed'>

# %%
plt.hist(df['cgpa'],bins=5)
# Out:
# (array([33., 23., 12., 24.,  8.]),
#  array([5.27 , 6.096, 6.922, 7.748, 8.574, 9.4  ]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['cgpa'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17344\2535591610.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
sns.boxplot(df['cgpa'])
# Out:
# <Axes: ylabel='cgpa'>
