# %% [markdown]
# # Standardization

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\Social_Network_Ads.csv")

# %%
x=df[['Age','EstimatedSalary']]
y=df['Purchased']

# %%
x.head(5)
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
x.isnull().sum() #there is no null values
# Out:
# Age                0
# EstimatedSalary    0
# dtype: int64

# %%
y.isnull().sum() #there is no null values
# Out:
# np.int64(0)

# %% [markdown]
# # Splitting data into test and train

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.head(5)
# Out:
#      Age  EstimatedSalary
# 95    35            44000
# 82    20            49000
# 73    33           113000
# 333   40            65000
# 398   36            33000

# %%
x_test.head(5)
# Out:
#      Age  EstimatedSalary
# 302   37           137000
# 104   19            21000
# 273   39           106000
# 310   42            70000
# 2     26            43000

# %%
y_train.head(5)
# Out:
# 95     0
# 82     0
# 73     0
# 333    0
# 398    0
# Name: Purchased, dtype: int64

# %%
y_test.head(5)
# Out:
# 302    1
# 104    0
# 273    1
# 310    0
# 2      0
# Name: Purchased, dtype: int64

# %%
#creating an object
scalar=StandardScaler()

# %%
x_scaled = scalar.fit(x_train)

# %%
scalar.transform(x_train) # range  -infinity to  +infinity       mean =0     standard deviation =1
# Out:
# array([[-0.24979753, -0.72266014],
#        [-1.66208039, -0.57611309],
#        [-0.43810191,  1.29968915],
#        [ 0.22096342, -0.10716253],
#        [-0.15564534, -1.04506365],
#        [-0.06149315,  0.30316921],
#        [-0.06149315,  0.2738598 ],
#        [ 1.53909409, -1.25022953],
#        [-0.81471068,  0.18593157],
#        [-0.24979753,  0.83073859],
#        [-0.06149315, -0.45887545],
#        [ 0.22096342,  1.12383269],
#        [ 0.88002876, -0.51749427],
#        [-0.81471068, -0.75196955],
#        [ 0.88002876, -0.75196955],
#        [-1.47377601, -1.48470481],
#        [-1.09716725, -1.54332363],
#        [ 0.12681123,  1.91518677],
#        [ 0.69172438, -1.07437306],
#        [-0.06149315,  2.26689969],
#        [-0.72055849,  1.38761738],
#        [ 0.78587657,  0.30316921],
#        [ 0.78587657,  0.5669539 ],
#        [ 0.88002876, -0.63473191],
#        [ 2.10400724, -0.66404132],
#        [ 1.91570286,  0.94797623],
#        [ 1.35078971,  0.62557272],
# ...

# %%
scalar.transform(x_test)
# Out:
# array([[-0.06149315,  2.003115  ],
#        [-1.75623258, -1.39677658],
#        [ 0.12681123,  1.09452328],
#        [ 0.4092678 ,  0.03938452],
#        [-1.09716725, -0.75196955],
#        [ 0.4092678 ,  0.30316921],
#        [ 1.06833314,  0.5669539 ],
#        [ 1.82155067,  1.56347385],
#        [-1.28547163, -0.3123284 ],
#        [ 1.4449419 ,  0.39109744],
#        [-0.34394972,  1.35830797],
#        [ 1.16248533,  0.5669539 ],
#        [ 1.25663752,  1.91518677],
#        [-1.09716725,  0.33247862],
#        [-0.06149315,  0.09800334],
#        [ 1.06833314,  0.59626331],
#        [-1.19131944,  0.53764449],
#        [ 0.12681123,  0.06869393],
#        [-1.66208039, -1.33815776],
#        [-1.09716725,  0.50833508],
#        [ 2.00985505,  0.42040685],
#        [ 0.12681123,  0.18593157],
#        [ 0.97418095,  1.82725854],
#        [-0.24979753, -1.27953894],
#        [ 0.22096342,  0.18593157],
#        [-0.90886287,  0.44971626],
#        [-1.00301506,  0.44971626],
# ...

# %% [markdown]
# # Normalization

# %%
# Why industry uses normalization

# Normalization is preferred when:

# Model expects bounded inputs

# Activation functions are sigmoid / tanh

# Input values must be comparable in magnitude

# This is more about numerical stability than statistics.

# Types of normalization (important)
# 1️⃣ Min–Max Normalization (most common)

# Range: [0, 1]

# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# X_norm = scaler.fit_transform(X)


# Used in:

# Neural Networks

# CNNs

# Image data

# UI / behavior metrics

# ⚠️ Sensitive to outliers

# 2️⃣ Min–Max (-1, 1)
# scaler = MinMaxScaler(feature_range=(-1, 1))


# Used when:

# tanh activation

# Zero-centered networks

# 3️⃣ MaxAbs Normalization
# 𝑥
# ′
# =
# 𝑥
# ∣
# 𝑥
# 𝑚
# 𝑎
# 𝑥
# ∣
# x
# ′
# =
# ∣x
# max
# 	​

# ∣
# x
# 	​

# from sklearn.preprocessing import MaxAbsScaler


# Used in:

# Sparse data

# NLP (TF-IDF)

# Recommender systems

# Preserves zeros ✔️

# %% [markdown]
# # 1️⃣ Min–Max Normalization (most common)

# %%
x_train.head(5)
# Out:
#      Age  EstimatedSalary
# 95    35            44000
# 82    20            49000
# 73    33           113000
# 333   40            65000
# 398   36            33000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_norm = scaler.fit_transform(x_train)


# Used in:

# Neural Networks

# CNNs

# Image data

# UI / behavior metrics

# ⚠️ Sensitive to outliers

# %%
x_test_norm=scaler.transform(x_test)

# %%
X_norm   #range  0 to 1
# Out:
# array([[0.4047619 , 0.21481481],
#        [0.04761905, 0.25185185],
#        [0.35714286, 0.72592593],
#        [0.52380952, 0.37037037],
#        [0.42857143, 0.13333333],
#        [0.45238095, 0.47407407],
#        [0.45238095, 0.46666667],
#        [0.85714286, 0.08148148],
#        [0.26190476, 0.44444444],
#        [0.4047619 , 0.60740741],
#        [0.45238095, 0.28148148],
#        [0.52380952, 0.68148148],
#        [0.69047619, 0.26666667],
#        [0.26190476, 0.20740741],
#        [0.69047619, 0.20740741],
#        [0.0952381 , 0.02222222],
#        [0.19047619, 0.00740741],
#        [0.5       , 0.88148148],
#        [0.64285714, 0.12592593],
#        [0.45238095, 0.97037037],
#        [0.28571429, 0.74814815],
#        [0.66666667, 0.47407407],
#        [0.66666667, 0.54074074],
#        [0.69047619, 0.23703704],
#        [1.        , 0.22962963],
#        [0.95238095, 0.63703704],
#        [0.80952381, 0.55555556],
#        [0.47619048, 0.41481481],
# ...

# %%
x_test_norm
# Out:
# array([[0.45238095, 0.9037037 ],
#        [0.02380952, 0.04444444],
#        [0.5       , 0.67407407],
#        [0.57142857, 0.40740741],
#        [0.19047619, 0.20740741],
#        [0.57142857, 0.47407407],
#        [0.73809524, 0.54074074],
#        [0.92857143, 0.79259259],
#        [0.14285714, 0.31851852],
#        [0.83333333, 0.4962963 ],
#        [0.38095238, 0.74074074],
#        [0.76190476, 0.54074074],
#        [0.78571429, 0.88148148],
#        [0.19047619, 0.48148148],
#        [0.45238095, 0.42222222],
#        [0.73809524, 0.54814815],
#        [0.16666667, 0.53333333],
#        [0.5       , 0.41481481],
#        [0.04761905, 0.05925926],
#        [0.19047619, 0.52592593],
#        [0.97619048, 0.5037037 ],
#        [0.5       , 0.44444444],
#        [0.71428571, 0.85925926],
#        [0.4047619 , 0.07407407],
#        [0.52380952, 0.44444444],
#        [0.23809524, 0.51111111],
#        [0.21428571, 0.51111111],
#        [0.83333333, 0.94814815],
# ...

# %% [markdown]
# # 2️⃣ Min–Max (-1, 1)

# %%
# Used when:

# tanh activation

# Zero-centered networks

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
x_train.head(5)
# Out:
#      Age  EstimatedSalary
# 95    35            44000
# 82    20            49000
# 73    33           113000
# 333   40            65000
# 398   36            33000

# %%
x_train_minmax= scaler.fit_transform(x_train)

# %%
x_test_minmax=scaler.transform(x_test)

# %%
x_train_minmax.min()
# Out:
# np.float64(-1.0)

# %%
x_train_minmax.max()
# Out:
# np.float64(1.0)

# %%
x_test_minmax.min()
# Out:
# np.float64(-0.9523809523809526)

# %%
x_test_minmax.max()
# Out:
# np.float64(1.0)

# %% [markdown]
# # 3️⃣ MaxAbs Normalization

# %%
# Used in:

# Sparse data

# NLP (TF-IDF)

# Recommender systems

# Preserves zeros ✔️

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
mabs=MaxAbsScaler()

# %%
x_train_mabs= mabs.fit_transform(x_train)

# %%
x_test_mabs= mabs.transform(x_test)

# %%
x_train_mabs.max()
# Out:
# np.float64(1.0)

# %%
x_train_mabs.min()
# Out:
# np.float64(0.1)

# %%
x_test_mabs.max()
# Out:
# np.float64(1.0)

# %%
x_test_mabs.min()
# Out:
# np.float64(0.13333333333333333)
