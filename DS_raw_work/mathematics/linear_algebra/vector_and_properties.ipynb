# %% [markdown]
# # dot product

# %%
v1=[-2,-3,-4,-1]
v2=[2,3,4,1]
cost=0
for i in range(0,len(v1)):
    cost=cost+(v1[i] * v2[i])
print(cost)
# Out:
# -30

# %%
import numpy as np

# %%
print(np.dot(v1,v2))
# Out:
# -30

# %% [markdown]
# # cosine similarity

# %%
# cosine similarity
similarity = (np.dot(v1,v2))/(np.linalg.norm(v1) * np.linalg.norm(v2) )
print(similarity)
# Out:
# -1.0

# %%
5.83 * 5.83
# Out:
# 33.9889

# %%
import numpy as np

unit_vec = [0.383, 0.613, 0.690]
angles = np.degrees(np.arccos(unit_vec))
# [67.5, 52.2, 46.4]
angles
# Out:
# array([67.48036619, 52.19325996, 46.36989113])
