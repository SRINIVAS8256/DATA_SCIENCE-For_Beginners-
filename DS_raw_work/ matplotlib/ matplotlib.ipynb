# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default')

# %% [markdown]
# #2d plot

# %%
df=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\kohli_ipl.csv")

# %%
df.set_index('match_no')
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=215, step=1)

# %%
plt.plot(df['match_no'],df['runs'])

# %% [markdown]
# plotting multiple plots

# %%
plt.plot(df['match_no'],df['runs'])

# %%
df2=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\placement.csv")
print(df2)
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
plt.plot(df2['cgpa'],df2['placed'],color='blue')
plt.plot(df2['placed'],df2['placed'],color='black')

# %%
df2=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\DataScience\\DataSets\\placement.csv")
print(df2)
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
plt.plot(df2['cgpa'],df2['placed'],color='blue')
plt.plot(df2['placed'],df2['placed'],color='black')
plt.xlabel('hi')
plt.ylabel('hello')
plt.text(0,1,'text')
# Out:
# Text(0, 1, 'text')

# %%
print("comeback")
# Out:
# comeback

# %%
import numpy as np
list1=np.array([1,2,3,4])
list2=np.array([1,2,3,4])
print(list1+list2)
# Out:
# [2 4 6 8]

# %%
a=np.array("16")
a=a.astype(int)
a.dtype
# Out:
# dtype('int64')
